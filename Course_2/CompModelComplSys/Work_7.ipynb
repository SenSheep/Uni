# %% [markdown]
# # БФБО-05-23 Баранов Арсений Юрьевич

# %% [markdown]
# ## Практика № 7 «Математическое моделирование»
# Напишите программы с использованием Python или C# для решения
# следующих задач:
# 1. Построить модель затухающих гармонических колебаний, для которых
# колебательный процесс описывается уравнениями вида:
# ![image.png](attachment:image.png)
# где e – основание натурального логарифма, δ – коэффициент затухания.
# Дискретное время вычислить по формуле: 𝑡[𝑛] = 𝑇0 ∗ 𝑛, где n=0,…,∞, 𝑇0 –
# период дискретизации модели.
# Рассчеты провести в соответствии с вариантом, представленном в таблице.
# ![image-2.png](attachment:image-2.png)

# %%
import math as m
import matplotlib.pyplot as plt

# Параметры функции
t0, a, w0, f0, q = 0, 1, 0.2, 0, 0.01
n = 1  # начальное значение n
y_values = []  # список для хранения значений y
t_values = []  # список для значений времени t

# Определение функций
def y():
    return a * m.exp(-q * t() * m.sin(f()))

def t():
    return t0 * n

def f():
    return wl() * t() + f0

def wl():
    return (w0**2 + q**2)**0.5

# Цикл для вычисления значений
for i in range(100):
    n = i + 1  # обновляем значение n
    if i % 5 == 0:
        t0 += 0.001  # обновление t0 каждые 5 итераций
    # Изменение параметров
    a -= 0.1
    w0 += 0.05
    f0 += 0.05
    q += 0.01
    # Вычисление и сохранение значений
    y_values.append(y())
    t_values.append(t())

# Построение графика
plt.plot(t_values, y_values, color="blue")
plt.xlabel("Time (t)")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
