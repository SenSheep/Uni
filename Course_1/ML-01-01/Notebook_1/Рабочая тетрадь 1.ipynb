# %% [markdown]
# ## Теоретический материал – Типы данных
# ### Типы данных
#
# Все типы данных в Python относятся к одной из 2-х категорий:
# изменяемые (mutable) и неизменяемые (immutable).
# Неизменяемые объекты:
#
# 1. числовые данные (int, float),
# 2. bool,
# 3. None,
# 4. символьные строки (class 'str'),
# 5. кортежи (tuple).
#
# Изменяемые объекты:
# 1. списки (list),
# 2. множества (set),
# 3. словари (dict).
#
# Определить тип переменной можно с помощью функции type().

# %% [markdown]
# ## Пример 1
# Выведите на печать и определите тип переменной x=5.

# %%
x = 5
print(x, type(x))
# Out:
# 5 <class 'int'>

# %% [markdown]
# ## Теоретический материал – Тип int
# C переменными типа int можно производить стандартные
# математические операции – сложение, вычитание, умножение, деление,
# возведение в степень, взятие остатка при делении на число.
#
# Деление переменных типа int бывает двух типов – целочисленное (с
# помощью символа //) и нецелочисленное (символ /). Результатом первого
# типа деления будет целое число, второго – дробное.

# %% [markdown]
# ## Пример 2
# Выполнить стандартные операции.

# %%
a = 4 + 5
b = 4 * 5
c = 5 // 4
d = 5 / 4
e = 5 ** 4
f = 5 % 4
print(a, b, c, d, e, d)
# Out:
# 9 20 1 1.25 625 1.25

# %% [markdown]
# ## Задание 1
# Приведите пример стандартных математических операций с переменной
# типа int.

# %%
print(f"Сложение: 8 + 2 =", 8 + 2)
print(f"Вычитание: 12 - 382 =", 12 - 382)
print(f"Умножение: 283 * 89 =", 283 * 89)
print(f"Деление: 2 / 2 =", 2 / 2)
# Out:
# Сложение: 8 + 2 = 10
# Вычитание: 12 - 382 = -370
# Умножение: 283 * 89 = 25187
# Деление: 2 / 2 = 1.0

# %% [markdown]
# ## Теоретический материал – Тип int
# Язык питон удобен в работе с большими числами.
# Во многих других языках (например, С++) присвоение большого числа
# переменной int вызвало ошибку - возникло бы переполнение.
# Давайте присвоим переменной большое число.

# %% [markdown]
# ## Пример 3.
# Присвоим переменной большое число 5000000000000000000000000001.

# %%
x = 5 * 1000000000 * 1000000000 * 10 ** 9 + 1
print(x, "|", type(x))
# Out:
# 5000000000000000000000000001 | <class 'int'>

# %% [markdown]
# ## Задание 2
# Присвойте переменной типа int большое число (значение указать
# больше, чем значение целочисленной переменной на языках класса СИ).

# %%
# Макс на C - 18 446 744 073 709 551 615
i = 18_446_744_073_709_551_616 # На единицу больше
print(i)
# Out:
# 18446744073709551616

# %% [markdown]
# ## Теоретический материал – Тип float
# C переменными типа float можно производить стандартные
# математические операции – сложение, вычитание, умножение, деление,
# возведение в степень, взятие остатка от деления на число.
# Переменную типа int можно привести к типу float.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Пример 4.
# Инициализируем переменную типа float. Разделитель точка.

# %%
y = 12.345
print(y, "|", type(y))
# Out:
# 12.345 | <class 'float'>

# %% [markdown]
# ## Пример 5
# Основные операции с переменной типа float.

# %%
af = 4.2 + 5.1
bf = 4.2 * 5.1
cf = 5.0 / 4.0
df = 5.25 // 4.25
ef = 5.25 ** 4.0
ff = 7.35 % 4.24
print(af, bf, cf, df, ef, ff)
# Округление до 2 знаков после запятой
round(bf, 2)
# Out:
# 9.3 21.419999999999998 1.25 1.0 759.69140625 3.1099999999999994
# 21.42

# %% [markdown]
# ## Задание 3
# Приведите пример стандартных операций с переменной типа float.
# Напишите комментарии к операциям в строке с операцией.
# Пример: af = 4.2 + 5.1 # сложение вещественных чисел.

# %%
af = 5.1 + 7.4 # Сложение
gf = 3.2 - 8.4 # Вычитание
bf = 6.8 * 4.8 # Умножение
cf = 9.3 / 1.5 # Деление
print(af, gf, bf, cf)
# Out:
# 12.5 -5.2 32.64 6.2

# %% [markdown]
# ## Теоретический материал – Тип bool
# Логический тип данных – принимает два значения: True или False.
#
# У типа bool существует связь с типом int – переменная со значением True
# соответствует int-овой переменной со значением 1, а переменная со значением
# False – int'овой переменной со значением 0.

# %% [markdown]
# ## Пример 6.
# Инициализируем переменные типа bool. Определим тип и убедимся, что тип
# bool

# %%
a = True
b = False
print(a, "|", type(a))
print(b, "|", type(b))
# Out:
# True | <class 'bool'>
# False | <class 'bool'>

# %% [markdown]
# ## Пример 7
# У типа bool существует связь с типом int.

# %%
print(a + b)
print(a + a)
print(b + b)
# Out:
# 1
# 2
# 0

# %% [markdown]
# ## Задание 4
# Приведите примеры переменных типа bool.
# У типа bool существует связь с типом int - переменная со значением True
# соответствует int'овой переменной со значением 1, а переменная со
# значением False - int'овой переменной со значением 0.
# Пример дополнить демонстрацией взаимосвязи с типом int.

# %%
a = True
b = False
an = 1
bn = 0
print(a == an, a == bn, b == an, b == bn, a + 1, an + 1, b + 1, bn + 1)
# Out:
# True False False True 2 2 1 1

# %% [markdown]
# ## Пример 8.
# Переменную типа bool можно привести к типу int.

# %%
a = True
b = False
print(int(a), int(b))
# Out:
# 1 0

# %% [markdown]
# ## Пример 9
# Проверим основные тождества.

# %%
print(True and False)
print(True or False)
print(not False)
# Out:
# False
# True
# True

# %% [markdown]
# ## Пример 10.
# Записать выражения
# a = (2 == 3)
# b = (4 < 5)
# Проверить тип результата. Комментарии приветствуются всегда.

# %%
a = (2 == 3)
b = (4 < 5)
print(a, "|", type(a))
print(b, "|", type(b))
# Out:
# False | <class 'bool'>
# True | <class 'bool'>

# %% [markdown]
# ## Пример 11.
# Определить результат
# 9/3>2*3 or not (12!=3**2+3 and 57-24>30)

# %%
print(9/3>2*3 or not(12!=3**2+3 and 57-24>30))
# Out:
# True

# %% [markdown]
# ## Теоретический материал – Функция input()
# Функция input() используется для ввода данных с клавиатуры.
# В примере 12 инициализируется переменная name – имя переменной.
# Имена переменных используются для хранения значений.
# Символ + используется для соединения (конкатенации) строк.

# %% [markdown]
# ## Пример 12.
# Введите с клавиатуры имя и скажите от имени программы привет.
# Python очень дружелюбный, позитивный и интуитивно понятный язык

# %%
name = input("Введите имя ")
print("Привет, " + name)
# Out:
# Введите имя Анна
# Привет, Анна

# %% [markdown]
# ## Пример 13.
# Введите с клавиатуры два целых числа и выполните сложение.

# %%
x = input("Введите x = ")
y = input("Введите y = ")
print(x + y)
# Out:
# Введите x = 4
# Введите y = 5
# 45

# %% [markdown]
# ## Задание 5.
# Присвойте переменной x значение БФБО, а переменной у номер группы и
# год поступления. Пример на конкатенацию – указать свою группу.

# %%
x = "БФБО"
y = "05-23"
print(x+"-"+y)
# Out:
# БФБО-05-23

# %% [markdown]
# ## Теоретический материал – Ввод с клавиатуры переменной
# Необходимо определять тип переменной при вводе с клавиатуры для
# выполнения арифметических операций.

# %% [markdown]
# ## Пример 14.
# Введите с клавиатуры два числа и выполните сложение

# %%
x = input("Введите x = ")
y = input("Введите y = ")
x = float(x)
y = float(y)
print(x + y)
# Out:
# Введите x = 4
# Введите y = 5
# 9.0

# %%
x = float(input("Введите x = "))
y = float(input("Введите y = "))
print(x+y, "|", type(x+y))
# Out:
# Введите x = 4
# Введите y = 5
# 9.0 | <class 'float'>

# %% [markdown]
# ## Задание 6.
# Введите с клавиатуры два числа, одно типа float, второе типа int. Выполните
# сложение. Определите тип данных результата.

# %%
a = int(input())
b = float(input())
print(a + b, type(a + b))
# Out:
# 6
# 3
# 9.0 <class 'float'>

# %% [markdown]
# ## Теоретический материал – Тип str
# Тип переменной "строка". Нужен для хранения и выполнения операций со
# строками – наборами символов. В Python строку можно задавать как с помощью
# одинарных кавычек, так и с помощью двойных, разницы нет (главное, чтобы в
# начале и конце одной строки стояли одинаковые кавычки).
# Со строками можно выполнять некоторые операции. Например, можно
# сложить две строки – вторая добавится в конец первой.
# Также у строк есть некоторое количество методов.
# Метод – это название для функций, которые вызываются от объекта.
# Например, у нас есть объект a – строка, и для нее можно вызвать метод .upper():
# a.upper()
# Методы делятся на те, которые изменяют сам объект, который их
# вызывает, и на те, которые возвращают результат, но не изменяют сам
# объект.
# Методы .upper() и .lower() – возвращают копию строки (не изменяя саму
# строку), для которой был вызван методы, приведения к верхнему и нижнему
# регистру соответственно.
# Внимание! При вызове метода какого-то класса (или функции какого-то
# модуля) можно написать его имя и через точку нажать [tab]:
# <имя_объекта_класса(модуля).[tab] – всплывет меню, в котором можно
# выбрать из всех существующих в этом классе методов (функций модуля).

# %% [markdown]
# ## Пример 15.
# Введите с клавиатуры имя и скажите от имени программы привет.
# Python очень дружелюбный, позитивный и интуитивно понятный язык.

# %%
name = input("Введите имя ")
print("Привет, " + name)
# Out:
# Введите имя Анна
# Привет, Анна

# %% [markdown]
# ## Пример 16.
# Задайте две переменные типа str, используя одинарные и двойные кавычки.
# Определите тип.

# %%
x = "abc"
y = "xyz"
print(x, "|", type(x))
print(y, "|", type(y))
# Out:
# abc | <class 'str'>
# xyz | <class 'str'>

# %% [markdown]
# ## Пример 17.
# Задайте две переменные типа str, используя одинарные и двойные кавычки.
# Сложите две строки

# %%
a = "Привет"
b = "Мир"
s = a + " " + b
print(s)
# Out:
# Привет Мир

# %% [markdown]
# ## Пример 18.
# Приведите строку а = ‘Привет’ к верхнему и нижнему регистру. Убедитесь,
# что данные методы возвращают результат, но не изменяют сам объект.

# %%
print(a.upper())
print(a.lower())
print(a)
# Out:
# ПРИВЕТ
# привет
# Привет

# %% [markdown]
# ## Задание 7.
# Присвойте переменной n значение ФИО, а переменной nn группы.
# Приведите переменные к верхнему регистру. Выполните сложение строк.
# Выведите на печать результат сложения. Покажите, что метод не изменил
# саму переменную.

# %%
n = "Баранов Арсений Юрьевич"
nn = "БФБО-05-23"
print(n.upper(), nn.upper())
print(n.upper() + nn.upper())
print(n, nn)
# Out:
# БАРАНОВ АРСЕНИЙ ЮРЬЕВИЧ БФБО-05-23
# БАРАНОВ АРСЕНИЙ ЮРЬЕВИЧБФБО-05-23
# Баранов Арсений Юрьевич БФБО-05-23

# %% [markdown]
# ## Теоретический материал – Тип None
# None – ничего, null
# Специальный тип в питоне, который обозначает “ничего”.
# Его нельзя привести ни к одному другому типу языка. Проверить, является
# ли переменная param типом None, можно так:
# if param is None
# С первого взгляда может быть непонятно, зачем он нужен, но на самом
# деле это очень удобный тип.
# Например, если вы где-то в коде создаете объект (базу данных, например),
# обращаясь к внешнему коду и хотите проверить, создалась ли ваша база данных,
# вы можете осуществить эту проверку, сравнив переменную базы данных с None.
# Примерно так:
# database = MyDatabase(db_host, db_user, db_password, db_database)
# if database is None

# %% [markdown]
# ## Пример 19.
# Задайте переменную None. Определите тип.

# %%
z = None
print(z, "|", type(z))
# Out:
# None | <class 'NoneType'>

# %% [markdown]
# ## Пример 20.
# Убедитесь, что None нельзя привести к другому типу

# %%
int(z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 int(z)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'

# %% [markdown]
# ## Пример 21.
# Проверьте переменную на None

# %%
if z is None:
    z = "I am None!"
z
# Out:
# 'I am None!'

# %% [markdown]
# ## Пример 22.
# Мы рассмотрели int, float, bool, None, str. К остальным очень важным типам
# данных и их специфики мы вернемся в дальнейшем.
# А пока давайте все-таки посмотрим и убедимся, что они существуют.

# %%
s = "ФИО"
s1 = 'Группа БФБО-0*-2022'
k = 5 # оценка за экзамен
q = k > 3 # хорошо успевающий студент
X = 3+5.2*7
y = None
z = 'a', 5, 12.345, (2, 'b')
df = [['Антонова Антонина', 34, 'ж'], ['Борисов Борис', 26, 'м']]
A = {1, 'title', 2, 'content'} 
print(s, '', type(s), '\n', s1, '|', type(s1), '\n',
      'Оценка за экзамен', k, '|', type(k), q, '|', type (q), '\n',
      x,'|', type(x), '\n', y, '|', type(y), '\n', 
      z, '|', type(z), '\n', df, '|', type (df), '\n', A, '|', type (A))
# Out:
# ФИО  <class 'str'>
#  Группа БФБО-0*-2022 | <class 'str'>
#  Оценка за экзамен 5 | <class 'int'> True | <class 'bool'>
#  abc | <class 'str'>
#  None | <class 'NoneType'>
#  ('a', 5, 12.345, (2, 'b')) | <class 'tuple'>
#  [['Антонова Антонина', 34, 'ж'], ['Борисов Борис', 26, 'м']] | <class 'list'>
#  {'title', 1, 2, 'content'} | <class 'set'>

# %% [markdown]
# ## Задание 8.
# По аналогии с примером, приведите свои примеры типов данных.
# Не забудьте инициализировать переменные и определить их тип ФИО и
# группа.

# %%
s = "ФИО"
s1 = "БФБО-**-**"
n = 60 #Баллы
q = n >= 60 #Результат БРС
n = 60 / 5
l = [s, s1]
print(s, type(s))
print(s1, type(s1))
print(n, type(n))
print(q, type(q))
print(n, type(n))
print(l, type(l))
# Out:
# ФИО <class 'str'>
# БФБО-**-** <class 'str'>
# 12.0 <class 'float'>
# True <class 'bool'>
# 12.0 <class 'float'>
# ['ФИО', 'БФБО-**-**'] <class 'list'>

# %% [markdown]
# ## Теоретический материал – Тип Set
# Множество – это набор, в котором элементы не повторяются (то есть,
# как и в математическом определении множества).
# Даже, если при задании элементов множества или копировании
# элементов массива в переменную типа множество будет указано несколько
# раз одинаковый элемент, при выводе множества можно убедится, что он
# будет один.
# Тип данных множество языка Python устроен совсем не так, как массив
# или кортеж, элементы множества хранятся не последовательно, поэтому к
# элементам множества нельзя обращаться по индексу.

# %% [markdown]
# ## Пример 23.
# Пустое множество можно создать с помощью set().

# %%
s_null = set()
print(s_null, "|", type(s_null))
# Out:
# set() | <class 'set'>

# %% [markdown]
# ## Пример 24.
# Задайте множество и проверьте его отличие от массива

# %%
s1 = {1, 2, 4, 2, 3, 5, 6, 7, 8, 5}
s1
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# ## Задание 9.
# По аналогии с примером, приведите свои примеры задания множества.
# Множество может включать переменные разных типов. При задании
# элементов множества укажите 5 элементов типа int (два одинаковых и
# для других типов тоже), 5 - типа float, 5 - элементов типа str.
# В комментарии опишите отличие множества от массива. Укажите
# мощность множества.

# %%
s = {1, 1,  2, 3, 4, 5, 1.5, 2.4, 3.3, 4.2, 5.1, "1", "2", "3", "4", "5"}
# Элементы не повторяются, хранится последовательно,
# нельзя обращаться по индексу
s
# Out:
# {1, '1', 1.5, 2, '2', 2.4, 3, '3', 3.3, 4, '4', 4.2, 5, '5', 5.1}

# %% [markdown]
# ## Теоретический материал – Операции над множествами
# Основные операции над множествами:
# 1) Объединение;
# 2) Пересечение;
# 3) Разность;
# 4) Симметричная разность.

# %% [markdown]
# ## Пример 25.
# Задайте два множества. Реализуйте операцию объединения.

# %%
a = {1, 2, 3, 7, 8}
b = {2, 3, 4, 5, 10, "apple"}
c = a | b
print(c)
# Out:
# {1, 2, 3, 4, 5, 7, 8, 10, 'apple'}

# %%
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5, 7, 8, 10, 'apple'}

# %% [markdown]
# ## Пример 26.
# Пересечение множеств.

# %%
c = a & b
print(c)
# Out:
# {2, 3}

# %%
print(a.intersection(b))
# Out:
# {2, 3}

# %% [markdown]
# ## Пример 27.
# Разность множеств.

# %%
c = a - b
print(c)
# Out:
# {8, 1, 7}

# %%
print(a.difference(b))
# Out:
# {8, 1, 7}

# %% [markdown]
# ## Пример 28.
# Симметричная разность множеств.

# %%
c = a ^ b
c
# Out:
# {1, 10, 4, 5, 7, 8, 'apple'}

# %%
print(a.symmetric_difference(b))
# Out:
# {1, 4, 5, 7, 8, 10, 'apple'}

# %% [markdown]
# ## Задание 10.
# По аналогии с примерами, приведите свои варианты операций над
# множествами. Не забывайте заголовки и комментарии – это хороший тон
# в программировании.

# %%
a = {1, 2, 3, "test"}
b = {5.2, False, 2, 95546}
print(a | b)
print(a & b)
print(a - b)
print(a ^ b)
# Out:
# {False, 1, 2, 3, 5.2, 'test', 95546}
# {2}
# {1, 3, 'test'}
# {False, 1, 3, 5.2, 'test', 95546}

# %% [markdown]
# ## Теоретический материал – Тип Set – модификация множеств
# Еще немного про множества.
# Можно добавлять элементы в множество с помощью метода .add()
# Можно удалить элементы по значению .discard(8)
# Посмотреть другие методы.
# При вызове метода какого-то класса (или функции какого-то модуля)
# можно написать его имя и через точку нажать tab:
# <имя_объекта_класса(модуля).[tab]
# Тогда всплывёт меню, в котором можно выбрать из всех
# существующих в этом классе методов (функций модуля).

# %% [markdown]
# ## Пример 29.
# Задайте множество A = {1, 2, 3, 7, 8}. Добавьте в множество переменные
# типов int, float, str, none. Напечатайте множество А.

# %%
a.add(1)
a.add("a")
a.add(None)
a.add(3.7)
print(a)
# Out:
# {1, 2, 3, 3.7, 'a', None, 'test'}

# %% [markdown]
# ## Пример 30.
# Внимание! Можно удалить элемент по значению, но не по индексу
# (отличие от массива нельзя обращаться к элементам по индексу).

# %%
a.discard(8)
a
# Out:
# {1, 2, 3, 3.7, None, 'a', 'test'}

# %% [markdown]
# ## Пример 31.
# Можно и другими методами изменять множество.
# При вызове метода какого-то класса (или функции какого-то модуля)
# можно написать его имя и через точку нажать [tab]:
# <имя_объекта_класса(модуля).[tab]
# Тогда всплывёт меню, в котором можно выбрать из всех существующих в
# этом классе методов (функций модуля).

# %%
a.update(["БФБО"],  [5])
a
# Out:
# {1, 2, 3, 3.7, 5, None, 'a', 'test', 'БФБО'}

# %%
"БФБО" in a
# Out:
# True

# %% [markdown]
# ## Задание 11.
# Задайте два множества
#
# Set1 = {1, 4, 5, 3, 5},
# Set2 = {4,5}.
#
# Примените к множеству Set2 метод .issubset(). В комментарии напишите,
# что определяет данный метод.

# %%
s1 = {1, 4, 5, 3, 5}
s2 = {4, 5}
print(s2.issubset(s1)) #Возвращает True, если все элементы во множестве s2
#существуют во множестве s1
# Out:
# True

# %% [markdown]
# ## Теоретический материал – Визализация множеств
# Комментарии в программах, описание разделов и методов - является
# важным аспектом любой программы.
# Инструментарий Jupyter очень обширен.
# Можно создавать заголовки, описание, код, визуализацию расчетов и
# комментарии к решаемым задачам - совокупность инструментов оценена
# аналитиками и учеными по данным, что определяет лидерство данных
# информационных технологий.
# Построим диаграммы Эйлера-Венна используя matplotlib_venn.
# from matplotlib_venn import venn2, venn2_unweighted, venn2_circles,
# venn3, venn3_circles
# from matplotlib import pyplot as plt

# %%
# !pip install matplotlib_venn
# Out:
# Collecting matplotlib_venn
#   Downloading matplotlib-venn-0.11.9.tar.gz (30 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: matplotlib in d:\anaconda\lib\site-packages (from matplotlib_venn) (3.7.1)
# Requirement already satisfied: numpy in d:\anaconda\lib\site-packages (from matplotlib_venn) (1.24.3)
# Requirement already satisfied: scipy in d:\anaconda\lib\site-packages (from matplotlib_venn) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib->matplotlib_venn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib->matplotlib_venn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib->matplotlib_venn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib->matplotlib_venn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib->matplotlib_venn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\lib\site-packages (from matplotlib->matplotlib_venn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\lib\site-packages (from matplotlib->matplotlib_venn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib->matplotlib_venn) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib->matplotlib_venn) (1.16.0)
# Building wheels for collected packages: matplotlib_venn
#   Building wheel for matplotlib_venn (pyproject.toml): started
#   Building wheel for matplotlib_venn (pyproject.toml): finished with status 'done'
#   Created wheel for matplotlib_venn: filename=matplotlib_venn-0.11.9-py3-none-any.whl size=33037 sha256=1a319037a5055007c85dd61add4fb3263fe2a9382346d5176eb723671ad787d9
#   Stored in directory: c:\users\sensheep\appdata\local\pip\cache\wheels\f6\80\48\193eff32ed8e176623b15874055438ecec522ba68ed05abee6
# Successfully built matplotlib_venn
# Installing collected packages: matplotlib_venn
# Successfully installed matplotlib_venn-0.11.9

# %%
# import modules
from matplotlib_venn import venn2, venn2_unweighted, venn2_circles, venn3, venn3_circles
from matplotlib import pyplot as plt

venn2_unweighted(subsets = (40, 20, 15), set_labels = ("Set A", "Set B"), 
                 set_colors = ("orange", "blue"), alpha = 0.7)

plt.show()

# %%
venn2(subsets = ([set([1, 2, 3, 4, 5]), set([2, 5, 4, 6, 7, 9, 15])]), set_labels = ("Set A", "Set B"), set_colors = ("orange", "blue"), alpha = 0.3)
plt.show()

# %% [markdown]
# ## Пример 34.
# Обратите внимание на параметры функции визуализации – задание
# множеств.
# Зададим два множества. Определим количество элементов в множестве AB, B-A, A&B. Построим диаграмму.

# %%
a = {1, 2, 3, 6, 7, 8}
b = {2, 3, 4, 5, 10}
an = len(a - b)
bm = len(b - a)
ci = len(a & b)
print(an, bm, ci)
# Out:
# 4 3 2

# %%
venn2(subsets = (an, bm, ci), set_labels = ("Set A", "Set B"), set_colors = ("orange", "blue"), alpha=0.2)
venn2_circles(subsets=(an, bm, ci))
plt.show()

# %% [markdown]
# ## Пример 35.
# Задать три множества. Построить диаграмму.

# %%
set_1 = {1, 2, 3, 4}
set_2 = {3, 4, 5}
set_3 = set_1 ^ set_2
venn3([set_1, set_2, set_3], set_colors=["steelblue", "orange", "green"], alpha=0.4)
venn3_circles(subsets=(set_1,set_2,set_3))
plt.show()

# %% [markdown]
# ## Задание 12.
# Задайте два множества. Постройте диаграммы Венна для двух множеств.

# %%
venn2(subsets = (100, 2, 1), set_labels = ("I don't know", "funny"), set_colors=("white", "black"), alpha=0.2)
venn2_circles(subsets=(100, 2, 1))
plt.show()

# %% [markdown]
# ## Задание 13.
# Задайте три множества. Постройте диаграммы Венна для трех множеств

# %%
set_1 = {8, 1, 6008, 565}
set_2 = {3, 6008, 1}
set_3 = set_1 ^ set_2
print(set_3)
venn3([set_1, set_2, set_3], set_colors=["white", "black", "purple"], alpha=0.4)
venn3_circles(subsets=(set_1,set_2,set_3))
plt.show()
# Out:
# {3, 565, 8}

# %% [markdown]
# ## Зaдание 14

# %%
u = {-5, -4, -3, -2, -1, 1, 2, 3, 4, 5}
a = {-1, 1, 2, 3}
b = {-3, -2, 1}
print(a or b)
print(b and a)
print(a | b)
print(b | a)
print((a | b) or (b | a))
print(not(b))
print(((a | b) or (b | a)) or ((b | a)))
# Out:
# {1, 2, 3, -1}
# {1, 2, 3, -1}
# {1, 2, 3, -2, -3, -1}
# {1, 2, 3, -1, -3, -2}
# {1, 2, 3, -2, -3, -1}
# False
# {1, 2, 3, -2, -3, -1}

# %% [markdown]
# ## Задача 15.1:
# Сумма первых n положительных целых чисел. n - вводится с клавиатуры.
# Код три (две) строки.

# %%
n = int(input())
print(((1 + n) / (2)) * n)
# Out:
# 6
# 21.0

# %% [markdown]
# ## Задача 15.2:
# Сортировка трех чисел по возрастанию.
# Без If и циклов.
# Например, используя min() и max().

# %%
list = [2, 3, 1]
l = []
l.append(min(list))
l.append(sum(list) - (max(list) + min(list)))
l.append(max(list))
print(l)
# Out:
# [1, 2, 3]

# %% [markdown]
# ![ChessUrl](https://media.tenor.com/GekDdVzKeaIAAAAd/turbo-cat-flex-on-cats-ex.gif "cat")
